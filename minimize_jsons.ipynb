# %%
import json
import glob

from help_code import load_json, save_json

# %%
def round_value(value):
    if isinstance(value, float):
        abs_val = abs(value)
        if abs_val == 0:
            return 0
        elif abs_val >= 1000:
            return round(value)
        elif abs_val >= 10:
            return round(value, 1)
        elif abs_val >= 1:
            return round(value, 2)
        elif abs_val >= 0.01:
            return round(value, 3)
        else:
            return float(f"{value:.2e}")
    return value

def minimize_json(data):
    if isinstance(data, dict):
        return {k: minimize_json(v) for k, v in data.items()}
    elif isinstance(data, list):
        return [minimize_json(v) for v in data]
    else:
        return round_value(data)

def calc_json_size(data):
    json_str = json.dumps(data, separators=(',', ':'))
    return len(json_str)

# %%
files = glob.glob('json/*.json')

for f in files:
    if 'min' not in f:
        json1 = load_json(f)
        json2 = minimize_json(json1)

        print(f'{f}: orig JSON={calc_json_size(json1)}, minimized JSON={calc_json_size(json2)}')

        name_out = f.replace('.json', '_min.json')
        save_json(json2, name_out, minimal=True)
# Out:
# json/rojals_web.json: orig JSON=3805, minimized JSON=2111
# json/pont-de-vilomara_web.json: orig JSON=6177, minimized JSON=3005
# json/orista_web.json: orig JSON=7277, minimized JSON=4051
# json/mequinensa_web.json: orig JSON=7919, minimized JSON=4068
# json/drunen_web.json: orig JSON=7675, minimized JSON=4476
# json/varnavas_web.json: orig JSON=5979, minimized JSON=3393
# json/san-patricio_web.json: orig JSON=32830, minimized JSON=17368
# json/patagual_web.json: orig JSON=15177, minimized JSON=8556
# json/ede_web.json: orig JSON=11270, minimized JSON=5553
# json/santa-coloma_2_web.json: orig JSON=19605, minimized JSON=8696
# json/junquillos_web.json: orig JSON=13579, minimized JSON=7451
# json/la-figuera_web.json: orig JSON=3263, minimized JSON=1574
# json/lavrio_web.json: orig JSON=2954, minimized JSON=1635
# json/tortosa_web.json: orig JSON=3872, minimized JSON=2021
# json/vilanova-da-meia_web.json: orig JSON=6285, minimized JSON=3305
# json/pauls_web.json: orig JSON=43990, minimized JSON=20169
# json/guissona_web.json: orig JSON=18696, minimized JSON=7815
# json/la-capellania_web.json: orig JSON=3464, minimized JSON=2191
# json/vega-honda_web.json: orig JSON=12674, minimized JSON=7171
# json/etos_web.json: orig JSON=1696, minimized JSON=1062
# json/thimari_web.json: orig JSON=2631, minimized JSON=1538
# json/manuel-rodriguez_web.json: orig JSON=13996, minimized JSON=8001
# json/granyena_web.json: orig JSON=12946, minimized JSON=7215
# json/batea_web.json: orig JSON=12749, minimized JSON=5323
# json/katsimidi_web.json: orig JSON=10350, minimized JSON=5234
# json/ell-valle-2_web.json: orig JSON=1262, minimized JSON=736
# json/martorell_web.json: orig JSON=14760, minimized JSON=7310
# json/santa-coloma_1_web.json: orig JSON=6273, minimized JSON=3426
