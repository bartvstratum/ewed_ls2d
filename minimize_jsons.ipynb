# %%
import json
import glob

from help_code import load_json, save_json

# %%
def round_value(value):
    if isinstance(value, float):
        abs_val = abs(value)
        if abs_val == 0:
            return 0
        elif abs_val >= 1000:
            return round(value)
        elif abs_val >= 10:
            return round(value, 1)
        elif abs_val >= 1:
            return round(value, 2)
        elif abs_val >= 0.01:
            return round(value, 3)
        else:
            return float(f"{value:.2e}")
    return value

def minimize_json(data):
    if isinstance(data, dict):
        return {k: minimize_json(v) for k, v in data.items()}
    elif isinstance(data, list):
        return [minimize_json(v) for v in data]
    else:
        return round_value(data)

def calc_json_size(data):
    json_str = json.dumps(data, separators=(',', ':'))
    return len(json_str)

# %%
files = glob.glob('json/*.json')

for f in files:
    if 'min' not in f:
        json1 = load_json(f)
        json2 = minimize_json(json1)

        print(f'{f}: orig JSON={calc_json_size(json1)}, minimized JSON={calc_json_size(json2)}')

        name_out = f.replace('.json', '_min.json')
        save_json(json2, name_out, minimal=True)
# Out:
# json/rojals_web.json: orig JSON=3805, minimized JSON=2111
# json/pont-de-vilomara_web.json: orig JSON=6177, minimized JSON=3005
# json/orista_web.json: orig JSON=7277, minimized JSON=4051
# json/mequinensa_web.json: orig JSON=7919, minimized JSON=4068
# json/varnavas_web.json: orig JSON=5979, minimized JSON=3393
# json/la-figuera_web.json: orig JSON=3263, minimized JSON=1574
# json/tortosa_web.json: orig JSON=3872, minimized JSON=2021
# json/vilanova-da-meia_web.json: orig JSON=6285, minimized JSON=3305
# json/santa-coloma_web.json: orig JSON=24241, minimized JSON=11202
# json/batea_web.json: orig JSON=12749, minimized JSON=5323
# json/katsimidi_web.json: orig JSON=10350, minimized JSON=5234
# json/martorel_web.json: orig JSON=14757, minimized JSON=7307

# %%
json2
# Out:
# {'reference': {'name': 'Martorel',
#   'description': 'Martorel - 2021-07-13T15:00:00 UTC',
#   'h': 1134,
#   'theta': 300.0,
#   'dtheta': 0.48,
#   'gamma_theta': [0.000418, 0.00938],
#   'z_theta': [3267, 4000],
#   'advtheta': 0,
#   'qt': 0.00535,
#   'dqt': -0.000535,
#   'gamma_qt': [-1.81e-07, -1.93e-06],
#   'z_qt': [2545, 4000],
#   'advq': 0,
#   'divU': 1e-05,
#   'u': 4.42,
#   'ug': 5.5,
#   'du': 1.07,
#   'gamma_u': [0.011, 0.001],
#   'z_u': [1200, 4000],
#   'advu': 0,
#   'v': 2.23,
#   'vg': -0.545,
#   'dv': -2.78,
#   'gamma_v': [-0.00369, -0.00177],
#   'z_v': [2198, 4000],
#   'advv': 0,
#   'ustar': 0.1,
#   'runtime': 10800,
#   'wtheta': [0.089, 0.055, 0.022, 2.51e-05, 0, 0, 0, 0, 0],
#   'wq': [8.16e-05,
#    7.19e-05,
#    5.63e-05,
#    4.19e-05,
#    3.25e-05,
#    3.27e-05,
#    3.02e-05,
#    2.03e-05,
#    1.57e-05],
#   'fc': 9.66e-05,
#   'p0': 98296,
#   'z0m': 0.232,
#   'z0h': 0.014,
#   'is_tuned': True,
#   't0': '2021-07-13T15:00:00Z'},
#  'preset': 'case_name',
#  'permutations': [],
#  'observations': [{'name': 'soundings/martorel/26-2021-07-13 17:05:07.csv',
#    'height': [0,
#     50,
#     100,
#     150,
#     200,
#     250,
#     300,
#     350,
#     400,
#     450,
#     500,
#     550,
#     600,
#     650,
#     700,
#     750,
#     800,
#     850,
#     900,
#     950,
#     1000,
#     1050,
#     1100,
#     1150,
#     1200,
#     1250,
#     1300,
#     1350,
#     1400,
#     1450,
#     1500,
#     1550,
#     1600,
#     1650,
#     1700,
#     1750,
#     1800,
#     1850,
#     1900,
#     1950,
#     2000,
#     2050,
#     2100,
#     2150,
#     2200,
#     2250,
#     2300,
#     2350],
#    'pressure': [1005,
#     999.7,
#     994.1,
#     988.7,
#     983.1,
#     977.7,
#     972.2,
#     966.8,
#     961.3,
#     955.9,
#     950.5,
#     945.1,
#     939.7,
#     934.4,
#     929.1,
#     923.8,
#     918.5,
#     913.2,
#     908.0,
#     902.8,
#     897.5,
#     892.3,
#     887.2,
#     882.0,
#     876.8,
#     871.7,
#     866.7,
#     861.6,
#     856.5,
#     851.5,
#     846.5,
#     841.4,
#     836.5,
#     831.6,
#     826.6,
#     821.7,
#     816.9,
#     812.0,
#     807.2,
#     802.4,
#     797.5,
#     792.8,
#     788.1,
#     783.3,
#     778.6,
#     773.9,
#     769.3,
#     764.6],
#    'temperature': [29.4,
#     33.3,
#     31.5,
#     31.3,
#     30.6,
#     29.7,
#     28.9,
#     27.8,
#     26.6,
#     25.7,
#     25.0,
#     23.9,
#     23.6,
#     23.4,
#     22.8,
#     22.4,
#     21.8,
#     21.3,
#     20.6,
#     20.0,
#     19.4,
#     18.3,
#     17.5,
#     16.9,
#     16.4,
#     15.9,
#     15.4,
#     15.0,
#     14.6,
#     14.0,
#     13.5,
#     13.0,
#     12.6,
#     12.3,
#     11.9,
#     11.7,
#     11.3,
#     11.0,
#     10.6,
#     10.1,
#     9.56,
#     9.16,
#     8.68,
#     8.26,
#     7.73,
#     6.68,
#     6.19,
#     5.71],
#    'relativeHumidity': [30.7,
#     28.3,
#     28.3,
#     29.1,
#     29.1,
#     30.0,
#     31.1,
#     31.3,
#     32.4,
#     34.4,
#     36.2,
#     37.3,
#     38.7,
#     38.9,
#     39.4,
#     39.9,
#     39.4,
#     39.7,
#     41.2,
#     42.4,
#     42.7,
#     43.9,
#     46.2,
#     48.1,
#     49.3,
#     51.0,
#     52.2,
#     53.0,
#     54.0,
#     55.7,
#     55.8,
#     56.9,
#     57.2,
#     57.1,
#     56.6,
#     56.2,
#     56.5,
#     56.7,
#     56.7,
#     58.2,
#     59.3,
#     60.5,
#     62.3,
#     63.4,
#     64.7,
#     67.9,
#     70.0,
#     71.5],
#    'windSpeed': [1.46,
#     8.53,
#     8.85,
#     6.97,
#     5.08,
#     4.08,
#     1.8,
#     2.92,
#     1.65,
#     2.17,
#     3.02,
#     3.68,
#     3.55,
#     3.75,
#     3.37,
#     2.57,
#     5.7,
#     2.43,
#     6.71,
#     3.06,
#     2.46,
#     2.65,
#     1.52,
#     1.65,
#     3.27,
#     5.45,
#     6.59,
#     4.84,
#     3.8,
#     4.83,
#     5.45,
#     8.3,
#     6.83,
#     8.55,
#     7.25,
#     8.68,
#     10.3,
#     10.7,
#     9.82,
#     10.6,
#     8.8,
#     10.1,
#     9.9,
#     9.07,
#     8.57,
#     8.98,
#     10.2,
#     9.88],
#    'windDirection': [154.9,
#     187.3,
#     194.9,
#     203.0,
#     205.4,
#     175.7,
#     163.0,
#     56.4,
#     301.5,
#     208.7,
#     274.8,
#     239.5,
#     277.4,
#     250.9,
#     269.9,
#     231.8,
#     177.9,
#     25.5,
#     40.0,
#     32.2,
#     52.2,
#     68.7,
#     83.5,
#     43.8,
#     111.1,
#     129.3,
#     93.3,
#     77.5,
#     82.3,
#     96.7,
#     137.1,
#     135.6,
#     103.3,
#     114.0,
#     110.3,
#     115.3,
#     107.0,
#     112.4,
#     110.5,
#     118.9,
#     124.1,
#     117.6,
#     128.8,
#     124.1,
#     125.4,
#     120.5,
#     136.1,
#     125.2]},
#   {'name': 'soundings/martorel/25-2021-07-13 16:25:11.csv',
#    'height': [0,
#     50,
#     100,
#     150,
#     200,
#     250,
#     300,
#     350,
#     400,
#     450,
#     500,
#     550,
#     600,
#     650,
#     700,
#     750,
#     800,
#     850,
#     900,
#     950,
#     1000,
#     1050,
#     1100,
#     1150,
#     1200,
#     1250,
#     1300,
#     1350,
#     1400,
#     1450,
#     1500,
#     1550,
#     1600,
#     1650,
#     1700,
#     1750,
#     1800,
#     1850,
#     1900,
#     1950,
#     2000,
#     2050,
#     2100,
#     2150,
#     2200,
#     2250,
#     2300,
#     2350,
#     2400,
#     2450,
#     2500,
#     2550,
#     2600,
#     2650,
#     2700,
#     2750,
#     2800,
#     2850,
#     2900,
#     2950,
#     3000,
#     3050,
#     3100,
#     3150,
#     3200,
#     3250,
#     3300,
#     3350,
#     3400,
#     3450],
#    'pressure': [996.5,
#     990.9,
#     985.3,
#     979.7,
#     974.2,
#     968.6,
#     963.2,
#     957.6,
#     952.2,
#     946.8,
#     941.4,
#     936.0,
#     930.6,
#     925.3,
#     920.0,
#     914.7,
#     909.4,
#     904.2,
#     899.0,
#     893.7,
#     888.5,
#     883.3,
#     878.2,
#     873.1,
#     868.0,
#     863.0,
#     857.9,
#     852.8,
#     847.8,
#     842.9,
#     837.9,
#     833.0,
#     828.0,
#     823.1,
#     818.3,
#     813.4,
#     808.5,
#     803.7,
#     799.0,
#     794.2,
#     789.4,
#     784.7,
#     780.0,
#     775.3,
#     770.7,
#     765.9,
#     761.3,
#     756.7,
#     752.2,
#     747.6,
#     743.1,
#     738.5,
#     734.1,
#     729.6,
#     725.1,
#     720.7,
#     716.3,
#     711.8,
#     707.5,
#     703.2,
#     698.8,
#     694.5,
#     690.3,
#     686.0,
#     681.7,
#     677.5,
#     673.4,
#     669.2,
#     665.1,
#     661.0],
#    'temperature': [32.1,
#     26.4,
#     25.8,
#     25.5,
#     25.1,
#     24.7,
#     24.2,
#     23.6,
#     23.2,
#     22.7,
#     22.3,
#     21.9,
#     21.3,
#     20.9,
#     20.4,
#     20.0,
#     19.5,
#     19.1,
#     18.6,
#     18.2,
#     17.5,
#     16.9,
#     17.0,
#     15.9,
#     15.7,
#     15.2,
#     14.8,
#     14.3,
#     13.9,
#     13.6,
#     13.3,
#     13.1,
#     12.7,
#     11.9,
#     11.7,
#     11.2,
#     10.6,
#     10.1,
#     9.67,
#     9.25,
#     8.76,
#     8.36,
#     7.86,
#     7.31,
#     7.14,
#     6.7,
#     6.19,
#     5.85,
#     5.22,
#     5.05,
#     4.65,
#     4.3,
#     3.82,
#     3.69,
#     3.34,
#     2.93,
#     2.37,
#     2.56,
#     2.33,
#     0.644,
#     -0.396,
#     -0.357,
#     0.3,
#     0.31,
#     0.25,
#     0.18,
#     -1.61,
#     1.39,
#     1.76,
#     1.43],
#    'relativeHumidity': [27.3,
#     34.3,
#     36.0,
#     36.3,
#     37.0,
#     37.8,
#     38.5,
#     39.1,
#     39.3,
#     39.9,
#     40.5,
#     41.2,
#     42.3,
#     41.6,
#     44.1,
#     45.0,
#     43.0,
#     46.9,
#     47.8,
#     48.9,
#     50.5,
#     52.2,
#     42.5,
#     54.3,
#     50.6,
#     54.1,
#     55.5,
#     57.4,
#     58.5,
#     59.0,
#     58.9,
#     58.7,
#     59.3,
#     53.3,
#     59.4,
#     63.7,
#     66.2,
#     68.1,
#     57.9,
#     66.7,
#     72.2,
#     69.2,
#     67.8,
#     79.3,
#     82.7,
#     85.3,
#     79.9,
#     89.5,
#     69.1,
#     57.8,
#     93.5,
#     88.7,
#     94.7,
#     80.1,
#     75.6,
#     95.8,
#     74.3,
#     96.6,
#     96.8,
#     93.3,
#     93.9,
#     95.2,
#     96.8,
#     97.2,
#     97.4,
#     97.3,
#     88.7,
#     88.5,
#     76.3,
#     73.2],
#    'windSpeed': [1.91,
#     6.45,
#     5.62,
#     3.67,
#     3.0,
#     4.5,
#     4.53,
#     3.82,
#     2.62,
#     2.65,
#     1.7,
#     1.13,
#     2.48,
#     2.58,
#     1.96,
#     2.8,
#     2.47,
#     2.95,
#     3.27,
#     5.05,
#     3.92,
#     3.2,
#     7.3,
#     5.22,
#     4.36,
#     0.05,
#     1.7,
#     4.7,
#     3.9,
#     2.74,
#     4.71,
#     3.8,
#     2.96,
#     7.64,
#     5.31,
#     2.97,
#     3.55,
#     2.32,
#     6.65,
#     3.68,
#     4.4,
#     5.53,
#     5.53,
#     4.38,
#     6.72,
#     5.96,
#     6.58,
#     5.65,
#     6.77,
#     7.31,
#     6.25,
#     6.74,
#     7.15,
#     8.27,
#     7.64,
#     7.15,
#     9.0,
#     7.75,
#     5.65,
#     6.58,
#     10.3,
#     7.42,
#     5.75,
#     6.1,
#     9.15,
#     7.38,
#     10.8,
#     7.95,
#     11.4,
#     13.0],
#    'windDirection': [257.9,
#     312.5,
#     317.9,
#     314.5,
#     296.2,
#     300.8,
#     300.9,
#     293.1,
#     290.8,
#     313.5,
#     341.7,
#     347.0,
#     336.0,
#     248.4,
#     290.4,
#     260.8,
#     195.7,
#     233.3,
#     226.9,
#     236.1,
#     237.1,
#     233.9,
#     106.6,
#     229.3,
#     192.3,
#     310.8,
#     262.6,
#     240.9,
#     233.5,
#     235.9,
#     238.2,
#     210.3,
#     220.8,
#     110.0,
#     165.4,
#     220.8,
#     199.7,
#     236.3,
#     117.2,
#     206.9,
#     181.9,
#     151.5,
#     150.9,
#     192.8,
#     182.1,
#     195.0,
#     169.2,
#     201.4,
#     133.6,
#     102.6,
#     171.4,
#     176.6,
#     182.0,
#     162.7,
#     154.2,
#     162.3,
#     140.4,
#     135.6,
#     142.0,
#     124.5,
#     133.5,
#     152.5,
#     185.3,
#     177.5,
#     186.5,
#     180.6,
#     154.3,
#     163.8,
#     142.2,
#     157.1]},
#   {'name': 'soundings/martorel/24-2021-07-13 16:09:22.csv',
#    'height': [0,
#     50,
#     100,
#     150,
#     200,
#     250,
#     300,
#     350,
#     400,
#     450,
#     500,
#     550,
#     600,
#     650,
#     700,
#     750,
#     800,
#     850,
#     900,
#     950,
#     1000,
#     1050,
#     1100,
#     1150,
#     1200,
#     1250,
#     1300,
#     1350,
#     1400,
#     1450,
#     1500,
#     1550,
#     1600,
#     1650,
#     1700,
#     1750,
#     1800,
#     1850,
#     1900,
#     1950,
#     2000,
#     2050,
#     2100,
#     2150,
#     2200,
#     2250,
#     2300,
#     2350,
#     2400,
#     2450,
#     2500,
#     2550,
#     2600,
#     2650,
#     2700,
#     2750,
#     2800,
#     2850,
#     2900,
#     2950,
#     3000,
#     3050,
#     3100,
#     3150,
#     3200,
#     3250,
#     3300,
#     3350,
#     3400,
#     3450,
#     3500,
#     3550,
#     3600,
#     3650,
#     3700],
#    'pressure': [988.2,
#     982.6,
#     977.0,
#     971.5,
#     965.9,
#     960.5,
#     955.1,
#     949.6,
#     944.2,
#     938.8,
#     933.4,
#     928.1,
#     922.8,
#     917.5,
#     912.2,
#     906.9,
#     901.6,
#     896.5,
#     891.3,
#     886.1,
#     881.0,
#     875.9,
#     870.8,
#     865.7,
#     860.6,
#     855.5,
#     850.5,
#     845.6,
#     840.6,
#     835.6,
#     830.7,
#     825.7,
#     820.9,
#     816.0,
#     811.2,
#     806.4,
#     801.5,
#     796.7,
#     792.0,
#     787.2,
#     782.5,
#     777.8,
#     773.1,
#     768.4,
#     763.8,
#     759.2,
#     754.6,
#     750.0,
#     745.4,
#     740.9,
#     736.4,
#     731.9,
#     727.4,
#     723.0,
#     718.6,
#     714.2,
#     709.8,
#     705.5,
#     701.1,
#     696.8,
#     692.6,
#     688.3,
#     684.1,
#     679.8,
#     675.6,
#     671.4,
#     667.2,
#     663.1,
#     658.9,
#     654.8,
#     650.7,
#     646.6,
#     642.5,
#     638.5,
#     634.5],
#    'temperature': [28.3,
#     26.6,
#     25.9,
#     25.4,
#     24.2,
#     24.0,
#     24.1,
#     24.2,
#     22.8,
#     22.1,
#     21.5,
#     20.9,
#     20.7,
#     20.6,
#     19.9,
#     19.2,
#     18.9,
#     18.6,
#     18.3,
#     18.0,
#     17.7,
#     17.3,
#     16.7,
#     16.1,
#     15.5,
#     14.9,
#     14.4,
#     13.9,
#     13.4,
#     12.9,
#     12.5,
#     12.1,
#     11.6,
#     11.2,
#     10.8,
#     10.3,
#     9.8,
#     9.26,
#     8.77,
#     8.28,
#     7.83,
#     7.31,
#     6.84,
#     6.38,
#     5.99,
#     5.47,
#     4.97,
#     4.58,
#     4.58,
#     4.42,
#     4.28,
#     4.16,
#     3.99,
#     3.87,
#     3.57,
#     3.1,
#     2.71,
#     2.27,
#     1.81,
#     -0.412,
#     -0.59,
#     -0.97,
#     -1.48,
#     -1.81,
#     -1.38,
#     -1.16,
#     -1.51,
#     -1.94,
#     -2.35,
#     -2.61,
#     -2.81,
#     -3.14,
#     -3.53,
#     -2.66,
#     -3.05],
#    'relativeHumidity': [36.0,
#     38.0,
#     38.9,
#     38.1,
#     37.6,
#     38.5,
#     38.6,
#     36.9,
#     38.0,
#     41.2,
#     42.6,
#     44.1,
#     45.9,
#     46.0,
#     47.1,
#     48.7,
#     49.6,
#     50.2,
#     50.9,
#     51.6,
#     52.3,
#     52.9,
#     53.6,
#     54.6,
#     55.7,
#     56.5,
#     58.2,
#     59.6,
#     60.9,
#     62.2,
#     63.7,
#     64.9,
#     66.3,
#     67.7,
#     69.5,
#     71.6,
#     73.2,
#     74.6,
#     73.8,
#     75.9,
#     78.8,
#     80.5,
#     82.4,
#     84.8,
#     86.8,
#     87.9,
#     88.9,
#     90.8,
#     93.0,
#     94.2,
#     94.8,
#     95.0,
#     95.0,
#     94.8,
#     94.1,
#     93.2,
#     92.7,
#     92.6,
#     92.5,
#     91.3,
#     91.4,
#     90.2,
#     99.5,
#     93.7,
#     95.1,
#     82.5,
#     83.0,
#     83.8,
#     84.9,
#     86.1,
#     87.1,
#     87.7,
#     86.6,
#     72.3,
#     61.5],
#    'windSpeed': [0.175,
#     5.5,
#     8.37,
#     8.44,
#     7.2,
#     7.05,
#     4.17,
#     5.15,
#     5.75,
#     6.75,
#     7.1,
#     4.22,
#     4.09,
#     4.48,
#     5.62,
#     4.31,
#     3.0,
#     5.8,
#     5.94,
#     6.07,
#     5.38,
#     5.36,
#     5.33,
#     5.31,
#     4.94,
#     4.3,
#     4.95,
#     4.1,
#     4.67,
#     5.51,
#     6.36,
#     5.16,
#     3.96,
#     2.77,
#     2.59,
#     2.41,
#     2.23,
#     2.05,
#     1.87,
#     1.86,
#     1.55,
#     0.817,
#     0.433,
#     0.05,
#     0.093,
#     0.105,
#     0.117,
#     0.083,
#     0.05,
#     1.33,
#     2.6,
#     4.08,
#     6.59,
#     9.11,
#     10.9,
#     10.8,
#     10.4,
#     10.0,
#     7.98,
#     12.1,
#     10.6,
#     9.95,
#     10.2,
#     9.3,
#     7.15,
#     8.01,
#     9.05,
#     10.1,
#     9.7,
#     10.6,
#     10.4,
#     9.47,
#     11.3,
#     12.4,
#     14.7],
#    'windDirection': [176.4,
#     291.2,
#     283.9,
#     280.0,
#     282.2,
#     285.3,
#     246.8,
#     296.0,
#     294.3,
#     283.8,
#     284.0,
#     274.0,
#     225.5,
#     239.9,
#     278.9,
#     275.9,
#     272.9,
#     217.1,
#     222.9,
#     228.6,
#     235.7,
#     248.8,
#     261.9,
#     275.0,
#     250.1,
#     261.4,
#     199.7,
#     232.7,
#     284.8,
#     267.9,
#     251.1,
#     247.3,
#     243.6,
#     239.8,
#     243.2,
#     246.7,
#     250.2,
#     253.6,
#     257.1,
#     161.2,
#     285.6,
#     75.6,
#     178.2,
#     280.8,
#     277.9,
#     154.2,
#     30.6,
#     38.0,
#     45.4,
#     69.2,
#     93.1,
#     119.2,
#     132.3,
#     145.5,
#     134.1,
#     126.2,
#     128.9,
#     132.4,
#     139.3,
#     126.3,
#     123.7,
#     115.5,
#     125.6,
#     123.6,
#     112.0,
#     127.0,
#     128.8,
#     130.5,
#     133.0,
#     115.2,
#     130.4,
#     136.8,
#     127.6,
#     113.8,
#     115.1]}]}
